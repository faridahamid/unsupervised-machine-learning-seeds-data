# %% [markdown]
# <a href="https://colab.research.google.com/github/faridahamid/unsupervised-machine-learning-seeds-data/blob/main/Unsupervised_seed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-fuzzy
# Out:
# Collecting scikit-fuzzy
#   Downloading scikit-fuzzy-0.4.2.tar.gz (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.25.2)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.11.4)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (3.2.1)
# Building wheels for collected packages: scikit-fuzzy
#   Building wheel for scikit-fuzzy (setup.py) ... done
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894077 sha256=45d171937358505287db33417b8156503a3c50827c0c611a3b137d6874e13e42
#   Stored in directory: /root/.cache/pip/wheels/4f/86/1b/dfd97134a2c8313e519bcebd95d3fedc7be7944db022094bc8
# Successfully built scikit-fuzzy
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.4.2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.spatial import distance_matrix
from scipy.special import comb
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import skfuzzy as fuzz
from sklearn.metrics import silhouette_score
# Import Fuzzy C-means (FCM)
from skfuzzy.cluster import cmeans ,cmeans_predict
from sklearn.metrics import pairwise_distances_argmin_min
from scipy.spatial import distance_matrix
from itertools import combinations
from scipy.spatial.distance import cdist

# %%
df=pd.read_csv("/content/seeds.csv")
df.shape
# Out:
# (199, 8)

# %%
df.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %% [markdown]
# # **Detecting** **Nulls**

# %%
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# Compactness        0
# Kernel.Length      0
# Kernel.Width       0
# Asymmetry.Coeff    0
# Kernel.Groove      0
# Type               0
# dtype: int64

# %% [markdown]
# NO Null data

# %% [markdown]
# # **Correlation Heatmap**

# %%
# Visualize correlation heatmap before preprocessing
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f")
print(df.corr())
plt.title('Correlation Heatmap of Features (Before Preprocessing)')
plt.show()
# Out:
#                      Area  Perimeter  Compactness  Kernel.Length  \
# Area             1.000000   0.994437     0.609887       0.951126
# Perimeter        0.994437   1.000000     0.531841       0.972944
# Compactness      0.609887   0.531841     1.000000       0.374011
# Kernel.Length    0.951126   0.972944     0.374011       1.000000
# Kernel.Width     0.970980   0.945496     0.762167       0.862680
# Asymmetry.Coeff -0.222820  -0.211034    -0.329400      -0.169704
# Kernel.Groove    0.862727   0.889543     0.227016       0.932124
# Type            -0.340664  -0.322223    -0.539261      -0.249422
#
#                  Kernel.Width  Asymmetry.Coeff  Kernel.Groove      Type
# Area                 0.970980        -0.222820       0.862727 -0.340664
# Perimeter            0.945496        -0.211034       0.889543 -0.322223
# Compactness          0.762167        -0.329400       0.227016 -0.539261
# Kernel.Length        0.862680        -0.169704       0.932124 -0.249422
# Kernel.Width         1.000000        -0.253122       0.748228 -0.421961
# Asymmetry.Coeff     -0.253122         1.000000      -0.003349  0.573956
# Kernel.Groove        0.748228        -0.003349       1.000000  0.035508
# Type                -0.421961         0.573956       0.035508  1.000000

# %% [markdown]
# # **patterns and correlations in the data**

# %%
num_features = df.shape[1]
fig, axes = plt.subplots(nrows=num_features, ncols=num_features, figsize=(15, 15))

for i in range(num_features):
    for j in range(num_features):
        axes[i, j].scatter(df.iloc[:, j], df.iloc[:, i], color='b', alpha=0.5)
        axes[i, j].set_xlabel('Feature {}'.format(j+1))
        axes[i, j].set_ylabel('Feature {}'.format(i+1))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df)
plt.show()

# %% [markdown]
# # **Detecting Outliers**

# %%
plt.figure(figsize=(10, 6))
df.boxplot()
plt.title('Boxplot Visualization of Features for Outlier Detection')
plt.ylabel('Feature Value')
plt.xlabel('Features')
plt.xticks(rotation=45)
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Dropping Target**

# %%
x=df.drop(columns=['Type'])

# %% [markdown]
# # **PCA**

# %%
scaler = StandardScaler()
X = scaler.fit_transform(x)

pca = PCA()

# Fit PCA to the scaled data
pca.fit(X)
# Out:
# PCA()

# %%
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Plot the cumulative variance ratio
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio, marker='o', linestyle='-')
plt.title('PCA visualization')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Variance Ratio')
plt.grid(True)
plt.show()

# %%
# Apply PCA with different numbers of components
pca_list = []
errors = []
for n_components in range(1, 8):
    pca = PCA(n_components=n_components)
    pca.fit(X)
    pca_list.append(pca)

# Compress and decompress the data with different numbers of components
for i, pca in enumerate(pca_list):
    compressed_data = pca.transform(X)
    decompressed_data = pca.inverse_transform(compressed_data)

    # Calculate the reconstruction error
    error = np.mean(np.square(X - decompressed_data))
    errors.append(error)


    print(f"Number of components: {i+1}")
    print(f"Reconstruction error: {error}")


optimal_components = np.argmin(errors) + 1


pca = PCA(n_components=optimal_components)
pca.fit(X)


transformed_data = pca.transform(X)
# Out:
# Number of components: 1
# Reconstruction error: 0.28121340998832445
# Number of components: 2
# Reconstruction error: 0.10990853575123707
# Number of components: 3
# Reconstruction error: 0.013306202724099452
# Number of components: 4
# Reconstruction error: 0.0035628999667019694
# Number of components: 5
# Reconstruction error: 0.0008754061970102798
# Number of components: 6
# Reconstruction error: 0.00011603966387925942
# Number of components: 7
# Reconstruction error: 1.5863305789817146e-31

# %%
print(f"Input data shape: {X.shape}")
print(f"Number of components used: {i+1}")
print(f"Number of components used for fitting: {pca.n_components}")
# Out:
# Input data shape: (199, 7)
# Number of components used: 1
# Number of components used for fitting: 7

# %%
from sklearn.metrics import mean_squared_error

plt.figure(figsize=(20, 10))
for i in range(1, 8):
    # Apply PCA
    pca = PCA(n_components=i)
    pca_1 = pca.fit_transform(X)

    X_new = pca.inverse_transform(pca_1)
    error = mean_squared_error(X, X_new)

    plt.subplot(2, 4, i)
    plt.scatter(X[:, 0], X[:, 1], edgecolor='red', s=50)
    plt.scatter(X_new[:, 0], X_new[:, 1], c='blue', marker='x')
    plt.title(f'Data  (PCA) ({i} components)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### optimal components is 5 or 6

# %%
pca_1 = PCA(n_components=5)
pca_1.fit(x)
df_compressed = pca_1.transform(x)

# %%
pca_2 = PCA(n_components=6)
pca_2.fit(x)
df_compressed_2 = pca_2.transform(x)

# %%
# Set the number of clusters
n_clusters = 3

# Set the fuzziness coefficient (m)
mvalues = [1.1, 1.5, 2]

# Perform fuzzy c-means clustering
for m in mvalues:
   cntr, u,_,_,_,_,_ = fuzz.cluster.cmeans(df_compressed.T, n_clusters, m, error=0.005, maxiter=1000)
   silhouette_fcm = silhouette_score(df_compressed, np.argmax(u ,axis=0))
   print(f"FCM m={m}: Silhouette Score = {silhouette_fcm:.4f}")
# Out:
# FCM m=1.1: Silhouette Score = 0.4729
# FCM m=1.5: Silhouette Score = 0.4729
# FCM m=2: Silhouette Score = 0.4729

# %%
# Set the number of clusters
n_clusters = 3

# Set the fuzziness coefficient (m)
mvalues = [1.1, 1.5, 2]

# Perform fuzzy c-means clustering
for m in mvalues:
   cntr, u,_,_,_,_,_ = fuzz.cluster.cmeans(df_compressed_2.T, n_clusters, m, error=0.005, maxiter=1000)
   silhouette_fcm = silhouette_score(df_compressed_2, np.argmax(u ,axis=0))
   print(f"FCM m={m}: Silhouette Score = {silhouette_fcm:.4f}")
# Out:
# FCM m=1.1: Silhouette Score = 0.4727
# FCM m=1.5: Silhouette Score = 0.4727
# FCM m=2: Silhouette Score = 0.4727

# %%
# Set the number of clusters
n_clusters = 3

# Set the fuzziness coefficient (m)
mvalues = [1.1, 1.5, 2]

# Perform fuzzy c-means clustering
for m in mvalues:
   cntr, u,_,_,_,_,_ = fuzz.cluster.cmeans(x.T, n_clusters, m, error=0.005, maxiter=1000)
   silhouette_fcm = silhouette_score(x, np.argmax(u ,axis=0))
   print(f"FCM m={m}: Silhouette Score = {silhouette_fcm:.4f}")
# Out:
# FCM m=1.1: Silhouette Score = 0.4727
# FCM m=1.5: Silhouette Score = 0.4727
# FCM m=2: Silhouette Score = 0.4727

# %%
x2 = x.drop(['Perimeter', 'Kernel.Length', 'Kernel.Width'], axis=1)

# %%
# Set the number of clusters
n_clusters = 3

# Set the fuzziness coefficient (m)
mvalues=[1.1,1.5,2]

# Perform fuzzy c-means clustering
for m in mvalues:
   cntr, u,_,_,_,_,_ = fuzz.cluster.cmeans(x2.T, n_clusters, m, error=0.005, maxiter=1000)
   silhouette_fcm = silhouette_score(x2, np.argmax(u ,axis=0))
   print(f"FCM m={m}: Silhouette Score = {silhouette_fcm:.4f}")
# Out:
# FCM m=1.1: Silhouette Score = 0.4689
# FCM m=1.5: Silhouette Score = 0.4689
# FCM m=2: Silhouette Score = 0.4689

# %%
n_clusters = 3
mvalues= [1.1,1.5,2]
for m in mvalues:
   cntr, u, _, _, _, _, _ = cmeans(data=x2.T, c=n_clusters, m=m, error=1e-5, maxiter=1000)
   entropy = -np.sum(u * np.log(u))
   silhouette_fcm = silhouette_score(x2, np.argmax(u, axis=0))
   print(f"FCM with Entropy  m={m}: Silhouette Score = {silhouette_fcm:.4f}, Entropy = {entropy:.4f}")
# Out:
# FCM with Entropy  m=1.1: Silhouette Score = 0.4689, Entropy = 4.9476
# FCM with Entropy  m=1.5: Silhouette Score = 0.4689, Entropy = 42.6023
# FCM with Entropy  m=2: Silhouette Score = 0.4689, Entropy = 100.8508

# %%
n_clusters = 3
mvalues = [1.1,1.5,2]
for m in mvalues:
   cntr, u,_,_,_,_,_ = fuzz.cluster.cmeans(data=x.T,c= n_clusters, m=m, error=1e-5, maxiter=1000)
   entropy = -np.sum(u * np.log(u))
   silhouette_fcm = silhouette_score(x2, np.argmax(u ,axis=0))
   print(f"FCM m={m}: Silhouette Score = {silhouette_fcm:.4f} ,Entropy = {entropy:.4f}")
# Out:
# FCM m=1.1: Silhouette Score = 0.4671 ,Entropy = 4.8989
# FCM m=1.5: Silhouette Score = 0.4671 ,Entropy = 40.8867
# FCM m=2: Silhouette Score = 0.4671 ,Entropy = 99.1605

# %%
n_clusters = 3
mvalues =[1.1,1.5,2]
for m in mvalues:

    cntr, u,_,_,_,_,_ = fuzz.cluster.cmeans(data=df_compressed.T,c= n_clusters, m=m, error=1e-5, maxiter=1000)
    entropy = -np.sum(u * np.log(u))
    silhouette_fcm = silhouette_score(df_compressed, np.argmax(u ,axis=0))
    print(f"FCM m={m}: Silhouette Score = {silhouette_fcm:.4f} ,Entropy = {entropy:.4f}")
# Out:
# FCM m=1.1: Silhouette Score = 0.4729 ,Entropy = 4.8992
# FCM m=1.5: Silhouette Score = 0.4729 ,Entropy = 40.8721
# FCM m=2: Silhouette Score = 0.4729 ,Entropy = 99.1236
